# %%
! streamlit hello
# Out:
#       👋 Welcome to Streamlit!
#
#       If you'd like to receive helpful onboarding emails, news, offers, promotions,
#       and the occasional swag, please enter your email address below. Otherwise,
#       leave this field blank.
#
#       Email: 2026-02-15 10:29:11.411
# ^C

# %%
import streamlit as st
import pandas as pd
from pathlib import Path

from valueSeek.processor import *
# Out:
# API key loaded.

# %%
df = read_financials(asPandas=True)
df.set_index('date')['revenue'].to_csv('AAPL_rev.csv')

# %%
st.write("""
# My first app
Hello *world!*         
""")
# Out:
# 2026-02-15 10:33:54.193 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-15 10:33:54.211
# ...
#   command:
#
#     streamlit run /home/abrahim/Documents/GitHub/valuescreen/vseek_env/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-02-15 10:33:54.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-15 10:33:54.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
